# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\Nirnoy Saha\\Desktop\\Deliveries IPL 2020.csv')

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0   1216492       1           MI          CSK     1     1  RG Sharma
# 1   1216492       1           MI          CSK     1     2  RG Sharma
# 2   1216492       1           MI          CSK     1     3  Q de Kock
# 3   1216492       1           MI          CSK     1     4  Q de Kock
# 4   1216492       1           MI          CSK     1     5  Q de Kock
#
#   non_striker     bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0   Q de Kock  DL Chahar              0  ...         0            0
# 1   Q de Kock  DL Chahar              0  ...         0            0
# 2   RG Sharma  DL Chahar              0  ...         0            0
# 3   RG Sharma  DL Chahar              0  ...         0            0
# 4   RG Sharma  DL Chahar              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             4           0           4
# 1            0             0             1           0           1
# 2            0             0             2           0           2
# 3            0             0             4           0           4
# 4            0             0             0           0           0
#
#    player_dismissed dismissal_kind fielder
# 0               NaN            NaN     NaN
# 1               NaN            NaN     NaN
# 2               NaN            NaN     NaN
# 3               NaN            NaN     NaN
# 4               NaN            NaN     NaN
#
# [5 rows x 21 columns]

# %%
filt = df['batsman']=='V Kohli'
df_kohli=df[filt]
df_kohli.shape
# Out:
# (393, 21)

# %%
df_kohli['batsman_runs'].value_counts().plot.pie()

# %%
len(df_kohli[df_kohli['batsman_runs']==4])
# Out:
# 24

# %%
len(df_kohli[df_kohli['batsman_runs']==6])
# Out:
# 12

# %%
def count(df,runs):
    return len(df_kohli[df_kohli['batsman_runs']==runs])*runs

# %%
count(df_kohli,1)
# Out:
# 193

# %%
count(df_kohli,2)
# Out:
# 106

# %%
count(df_kohli,3)
# Out:
# 6

# %%
count(df_kohli,4)
# Out:
# 96

# %%
count(df_kohli,6)
# Out:
# 72

# %%
slices = [193,106,6,96,72]
labels = [1,2,3,4,6]
explode=[0.1,0,0,0,0]
plt.pie(slices,labels=labels,autopct='%1.1f',explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x17040bd7c10>,
#   <matplotlib.patches.Wedge at 0x17040bd7d00>,
#   <matplotlib.patches.Wedge at 0x17040bef070>,
#   <matplotlib.patches.Wedge at 0x17040bef5e0>,
#   <matplotlib.patches.Wedge at 0x17040bc4040>],
#  [Text(0.34190091024658364, 1.1502624776860966, '1'),
#   Text(-1.0912527681384994, -0.1384463651746138, '2'),
#   Text(-0.7092405450691386, -0.8408197483587261, '3'),
#   Text(-0.02556881449202887, -1.099702794270103, '4'),
#   Text(0.9766006657256892, -0.5062125440011743, '6')],
#  [Text(0.19944219764384044, 0.6709864453168896, '40.8'),
#   Text(-0.5952287826209997, -0.07551619918615299, '22.4'),
#   Text(-0.386858479128621, -0.45862895365021417, '1.3'),
#   Text(-0.013946626086561201, -0.5998378877836925, '20.3'),
#   Text(0.5326912722140122, -0.2761159330915496, '15.2')])

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0   1216492       1           MI          CSK     1     1  RG Sharma
# 1   1216492       1           MI          CSK     1     2  RG Sharma
# 2   1216492       1           MI          CSK     1     3  Q de Kock
# 3   1216492       1           MI          CSK     1     4  Q de Kock
# 4   1216492       1           MI          CSK     1     5  Q de Kock
#
#   non_striker     bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0   Q de Kock  DL Chahar              0  ...         0            0
# 1   Q de Kock  DL Chahar              0  ...         0            0
# 2   RG Sharma  DL Chahar              0  ...         0            0
# 3   RG Sharma  DL Chahar              0  ...         0            0
# 4   RG Sharma  DL Chahar              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             4           0           4
# 1            0             0             1           0           1
# 2            0             0             2           0           2
# 3            0             0             4           0           4
# 4            0             0             0           0           0
#
#    player_dismissed dismissal_kind fielder
# 0               NaN            NaN     NaN
# 1               NaN            NaN     NaN
# 2               NaN            NaN     NaN
# 3               NaN            NaN     NaN
# 4               NaN            NaN     NaN
#
# [5 rows x 21 columns]

# %%
df['bowling_team'].unique()
# Out:
# array(['CSK', 'MI', 'KXIP', 'DC', 'SRH', 'RCB', 'RR', 'KKR'], dtype=object)

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
runs=df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
runs.drop('match_id',axis=1,inplace=True)
runs
# Out:
#      inning batting_team  total_runs
# 0         1           MI         162
# 1         2          CSK         166
# 2         1           DC         155
# 3         1         KXIP           2
# 4         2           DC           3
# ..      ...          ...         ...
# 123       2          SRH         132
# 124       1           DC         189
# 125       2          SRH         172
# 126       1           DC         155
# 127       2           MI         157
#
# [128 rows x 3 columns]

# %%
inning1 = runs[runs['inning']==1]
inning2 = runs[runs['inning']==1]

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning1)

# %%
sns.boxplot(x='batting_team',y='total_runs',data=inning2)

# %%
high_score = df.groupby(['match_id','inning','batting_team','bowling_team'])['total_runs'].sum().reset_index()
high_score
# Out:
#      match_id  inning batting_team bowling_team  total_runs
# 0     1216492       1           MI          CSK         162
# 1     1216492       2          CSK           MI         166
# 2     1216493       1           DC         KXIP         155
# 3     1216493       1         KXIP           DC           2
# 4     1216493       2           DC         KXIP           3
# ..        ...     ...          ...          ...         ...
# 123   1237178       2          SRH          RCB         132
# 124   1237180       1           DC          SRH         189
# 125   1237180       2          SRH           DC         172
# 126   1237181       1           DC           MI         155
# 127   1237181       2           MI           DC         157
#
# [128 rows x 5 columns]

# %%
score_200 = high_score[high_score['total_runs']>=200]
score_200
# Out:
#      match_id  inning batting_team bowling_team  total_runs
# 10    1216496       1           RR          CSK         215
# 11    1216496       2          CSK           RR         200
# 14    1216498       1         KXIP          SRH         252
# 15    1216498       2          SRH         KXIP         228
# 38    1216510       1         KXIP          RCB         204
# 50    1216515       1           DC          KKR         228
# 51    1216515       2          KKR           DC         210
# 70    1216524       1          SRH           DC         219
# 76    1216527       1         KXIP           RR         222
# 77    1216527       2           RR         KXIP         226
# 98    1216538       1           MI          SRH         208
# 106   1216542       1          SRH         KXIP         201
# 117   1216547       1          RCB           MI         201
# 118   1216547       2           MI          RCB         201
# 120   1237177       1           MI           DC         200

# %%
sns.countplot(score_200['batting_team'])

# %%
sns.countplot(score_200['bowling_team'])

# %%
balls = df.groupby('batsman')['ball'].count().reset_index()
balls
# Out:
#                batsman  ball
# 0       AB de Villiers   288
# 1           AD Russell    74
# 2             AJ Finch   249
# 3               AJ Tye     6
# 4            AM Rahane   111
# ..                 ...   ...
# 128           VR Aaron     9
# 129            WP Saha   157
# 130  Washington Sundar    93
# 131        YBK Jaiswal    42
# 132          YS Chahal     5
#
# [133 rows x 2 columns]

# %%
runs = df.groupby('batsman')['batsman_runs'].sum().reset_index()
runs
# Out:
#                batsman  batsman_runs
# 0       AB de Villiers           443
# 1           AD Russell           125
# 2             AJ Finch           266
# 3               AJ Tye             6
# 4            AM Rahane           113
# ..                 ...           ...
# 128           VR Aaron             1
# 129            WP Saha           214
# 130  Washington Sundar           111
# 131        YBK Jaiswal            40
# 132          YS Chahal             1
#
# [133 rows x 2 columns]

# %%
four = df[df['batsman_runs']==4]
four
# Out:
#        match_id  inning batting_team bowling_team  over  ball       batsman  \
# 0       1216492       1           MI          CSK     1     1     RG Sharma
# 3       1216492       1           MI          CSK     1     4     Q de Kock
# 9       1216492       1           MI          CSK     2     4     RG Sharma
# 16      1216492       1           MI          CSK     3     5     Q de Kock
# 19      1216492       1           MI          CSK     4     2     Q de Kock
# ...         ...     ...          ...          ...   ...   ...           ...
# 14305   1237181       2           MI           DC    16     2  Ishan Kishan
# 14306   1237181       2           MI           DC    16     3  Ishan Kishan
# 14313   1237181       2           MI           DC    17     4    KA Pollard
# 14314   1237181       2           MI           DC    17     5    KA Pollard
# 14318   1237181       2           MI           DC    18     3  Ishan Kishan
#
#         non_striker         bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0         Q de Kock      DL Chahar              0  ...         0            0
# 3         RG Sharma      DL Chahar              0  ...         0            0
# 9         Q de Kock       S Curran              0  ...         0            0
# 16        RG Sharma      DL Chahar              0  ...         0            0
# 19        RG Sharma        L Ngidi              0  ...         0            0
# ...             ...            ...            ...  ...       ...          ...
# 14305     RG Sharma  Praveen Dubey              0  ...         0            0
# 14306     RG Sharma  Praveen Dubey              0  ...         0            0
# 14313  Ishan Kishan  Anrich Nortje              0  ...         0            0
# 14314  Ishan Kishan  Anrich Nortje              0  ...         0            0
# 14318     HH Pandya       K Rabada              0  ...         0            0
#
#        noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0                0             0             4           0           4
# 3                0             0             4           0           4
# 9                0             0             4           0           4
# 16               0             0             4           0           4
# 19               0             0             4           0           4
# ...            ...           ...           ...         ...         ...
# 14305            0             0             4           0           4
# 14306            0             0             4           0           4
# 14313            0             0             4           0           4
# 14314            0             0             4           0           4
# 14318            0             0             4           0           4
#
#        player_dismissed dismissal_kind fielder
# 0                   NaN            NaN     NaN
# 3                   NaN            NaN     NaN
# 9                   NaN            NaN     NaN
# 16                  NaN            NaN     NaN
# 19                  NaN            NaN     NaN
# ...                 ...            ...     ...
# 14305               NaN            NaN     NaN
# 14306               NaN            NaN     NaN
# 14313               NaN            NaN     NaN
# 14314               NaN            NaN     NaN
# 14318               NaN            NaN     NaN
#
# [1605 rows x 21 columns]

# %%
runs_4 = four.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4.columns=['batsman','4s']
runs_4
# Out:
#               batsman  4s
# 0      AB de Villiers  32
# 1          AD Russell  10
# 2            AJ Finch  29
# 3           AM Rahane  12
# 4            AR Patel   2
# ..                ...  ..
# 95            V Kohli  24
# 96          V Shankar  14
# 97            WP Saha  24
# 98  Washington Sundar  10
# 99        YBK Jaiswal   2
#
# [100 rows x 2 columns]

# %%
six = df[df['batsman_runs']==6]
six
# Out:
#        match_id  inning batting_team bowling_team  over  ball       batsman  \
# 49      1216492       1           MI          CSK     9     2     SS Tiwary
# 71      1216492       1           MI          CSK    12     5     HH Pandya
# 72      1216492       1           MI          CSK    12     6     HH Pandya
# 90      1216492       1           MI          CSK    16     2    KA Pollard
# 153     1216492       2          CSK           MI     6     7     AT Rayudu
# ...         ...     ...          ...          ...   ...   ...           ...
# 14237   1237181       2           MI           DC     4     6     RG Sharma
# 14240   1237181       2           MI           DC     5     3      SA Yadav
# 14264   1237181       2           MI           DC     9     3     RG Sharma
# 14266   1237181       2           MI           DC     9     5     RG Sharma
# 14301   1237181       2           MI           DC    15     4  Ishan Kishan
#
#         non_striker         bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 49         AS Yadav      RA Jadeja              0  ...         0            0
# 71         AS Yadav      RA Jadeja              0  ...         0            0
# 72         AS Yadav      RA Jadeja              0  ...         0            0
# 90        KH Pandya      PP Chawla              0  ...         0            0
# 153    F du Plessis      JJ Bumrah              0  ...         0            0
# ...             ...            ...            ...  ...       ...          ...
# 14237     Q de Kock  Anrich Nortje              0  ...         0            0
# 14240     RG Sharma     MP Stoinis              0  ...         0            0
# 14264      SA Yadav  Praveen Dubey              0  ...         0            0
# 14266      SA Yadav  Praveen Dubey              0  ...         0            0
# 14301     RG Sharma     MP Stoinis              0  ...         0            0
#
#        noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 49               0             0             6           0           6
# 71               0             0             6           0           6
# 72               0             0             6           0           6
# 90               0             0             6           0           6
# 153              0             0             6           0           6
# ...            ...           ...           ...         ...         ...
# 14237            0             0             6           0           6
# 14240            0             0             6           0           6
# 14264            0             0             6           0           6
# 14266            0             0             6           0           6
# 14301            0             0             6           0           6
#
#        player_dismissed dismissal_kind fielder
# 49                  NaN            NaN     NaN
# 71                  NaN            NaN     NaN
# 72                  NaN            NaN     NaN
# 90                  NaN            NaN     NaN
# 153                 NaN            NaN     NaN
# ...                 ...            ...     ...
# 14237               NaN            NaN     NaN
# 14240               NaN            NaN     NaN
# 14264               NaN            NaN     NaN
# 14266               NaN            NaN     NaN
# 14301               NaN            NaN     NaN
#
# [736 rows x 21 columns]

# %%
runs_6 = six.groupby('batsman')['batsman_runs'].count().reset_index()
runs_6.columns=['batsman','6s']
runs_6
# Out:
#               batsman  6s
# 0      AB de Villiers  22
# 1          AD Russell  10
# 2            AJ Finch   7
# 3              AJ Tye   1
# 4           AM Rahane   2
# ..                ...  ..
# 75            V Kohli  12
# 76          V Shankar   1
# 77            WP Saha   5
# 78  Washington Sundar   2
# 79        YBK Jaiswal   2
#
# [80 rows x 2 columns]

# %%
player = pd.concat([runs,balls.iloc[:,1],runs_4.iloc[:,1],runs_6.iloc[:,1]],axis=1)
player
# Out:
#                batsman  batsman_runs  ball    4s    6s
# 0       AB de Villiers           443   288  32.0  22.0
# 1           AD Russell           125    74  10.0  10.0
# 2             AJ Finch           266   249  29.0   7.0
# 3               AJ Tye             6     6  12.0   1.0
# 4            AM Rahane           113   111   2.0   2.0
# ..                 ...           ...   ...   ...   ...
# 128           VR Aaron             1     9   NaN   NaN
# 129            WP Saha           214   157   NaN   NaN
# 130  Washington Sundar           111    93   NaN   NaN
# 131        YBK Jaiswal            40    42   NaN   NaN
# 132          YS Chahal             1     5   NaN   NaN
#
# [133 rows x 5 columns]

# %%
player.fillna(0,inplace=True)
player
# Out:
#                batsman  batsman_runs  ball    4s    6s
# 0       AB de Villiers           443   288  32.0  22.0
# 1           AD Russell           125    74  10.0  10.0
# 2             AJ Finch           266   249  29.0   7.0
# 3               AJ Tye             6     6  12.0   1.0
# 4            AM Rahane           113   111   2.0   2.0
# ..                 ...           ...   ...   ...   ...
# 128           VR Aaron             1     9   0.0   0.0
# 129            WP Saha           214   157   0.0   0.0
# 130  Washington Sundar           111    93   0.0   0.0
# 131        YBK Jaiswal            40    42   0.0   0.0
# 132          YS Chahal             1     5   0.0   0.0
#
# [133 rows x 5 columns]

# %%
player['strike_rate']=player['batsman_runs']/player['ball']*100
player
# Out:
#                batsman  batsman_runs  ball    4s    6s  strike_rate
# 0       AB de Villiers           443   288  32.0  22.0   153.819444
# 1           AD Russell           125    74  10.0  10.0   168.918919
# 2             AJ Finch           266   249  29.0   7.0   106.827309
# 3               AJ Tye             6     6  12.0   1.0   100.000000
# 4            AM Rahane           113   111   2.0   2.0   101.801802
# ..                 ...           ...   ...   ...   ...          ...
# 128           VR Aaron             1     9   0.0   0.0    11.111111
# 129            WP Saha           214   157   0.0   0.0   136.305732
# 130  Washington Sundar           111    93   0.0   0.0   119.354839
# 131        YBK Jaiswal            40    42   0.0   0.0    95.238095
# 132          YS Chahal             1     5   0.0   0.0    20.000000
#
# [133 rows x 6 columns]

# %%
grp= df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()
grp
# Out:
#      match_id       batsman batting_team  batsman_runs
# 0     1216492      AS Yadav           MI            17
# 1     1216492     AT Rayudu          CSK            67
# 2     1216492  F du Plessis          CSK            58
# 3     1216492     HH Pandya           MI            14
# 4     1216492     JJ Bumrah           MI             5
# ..        ...           ...          ...           ...
# 845   1237181       RR Pant           DC            56
# 846   1237181      S Dhawan           DC            15
# 847   1237181     S Hetmyer           DC             5
# 848   1237181      SA Yadav           MI            19
# 849   1237181       SS Iyer           DC            64
#
# [850 rows x 4 columns]

# %%
max = grp.groupby('batsman')['batsman_runs'].max().reset_index()
max.columns=['batsman','max_runs']
max
# Out:
#                batsman  max_runs
# 0       AB de Villiers        65
# 1           AD Russell        25
# 2             AJ Finch        52
# 3               AJ Tye         6
# 4            AM Rahane        60
# ..                 ...       ...
# 128           VR Aaron         1
# 129            WP Saha        87
# 130  Washington Sundar        30
# 131        YBK Jaiswal        34
# 132          YS Chahal         1
#
# [133 rows x 2 columns]

# %%
player2 = pd.concat([player,max.iloc[:,1]],axis=1)
player2
# Out:
#                batsman  batsman_runs  ball    4s    6s  strike_rate  max_runs
# 0       AB de Villiers           443   288  32.0  22.0   153.819444        65
# 1           AD Russell           125    74  10.0  10.0   168.918919        25
# 2             AJ Finch           266   249  29.0   7.0   106.827309        52
# 3               AJ Tye             6     6  12.0   1.0   100.000000         6
# 4            AM Rahane           113   111   2.0   2.0   101.801802        60
# ..                 ...           ...   ...   ...   ...          ...       ...
# 128           VR Aaron             1     9   0.0   0.0    11.111111         1
# 129            WP Saha           214   157   0.0   0.0   136.305732        87
# 130  Washington Sundar           111    93   0.0   0.0   119.354839        30
# 131        YBK Jaiswal            40    42   0.0   0.0    95.238095        34
# 132          YS Chahal             1     5   0.0   0.0    20.000000         1
#
# [133 rows x 7 columns]

# %%
max_runs=df.groupby('batsman')['batsman_runs'].sum()
max_runs.sort_values(ascending=False)[:10].plot(kind='bar')

# %%
df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index().sort_values(by='batsman_runs',ascending=False).head(10)
# Out:
#      match_id       batsman batting_team  batsman_runs
# 282   1216510      KL Rahul         KXIP           132
# 508   1216527    MA Agarwal         KXIP           110
# 700   1216541     BA Stokes           RR           107
# 776   1216546      S Dhawan           DC           106
# 273   1216509      S Dhawan           DC           101
# 646   1216537      CH Gayle         KXIP           100
# 784   1216547  Ishan Kishan           MI            99
# 716   1216542    J Bairstow          SRH            98
# 24    1216493    MA Agarwal         KXIP            89
# 47    1216495     DA Warner          SRH            89

# %%
df['dismissal_kind'].unique()
# Out:
# array([nan, 'bowled', 'lbw', 'hit wicket', 'caught', 'run out', 'stumped'],
#       dtype=object)

# %%
dismissal_kinds = ['bowled', 'lbw', 'hit wicket', 'caught', 'stumped']

# %%
hwt = df[df['dismissal_kind'].isin(dismissal_kinds )]
hwt.head()
# Out:
#      match_id  inning batting_team bowling_team  over  ball    batsman  \
# 110   1216492       1           MI          CSK    20     1   TA Boult
# 121   1216492       2          CSK           MI     1     6  SR Watson
# 128   1216492       2          CSK           MI     2     7    M Vijay
# 221   1216492       2          CSK           MI    18     1  RA Jadeja
# 317   1216493       1           DC         KXIP    14     6    RR Pant
#
#       non_striker        bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 110     RD Chahar     DL Chahar              0  ...         0            0
# 121       M Vijay      TA Boult              0  ...         0            0
# 128     AT Rayudu  JL Pattinson              0  ...         0            0
# 221  F du Plessis     MK Pandey              0  ...         0            0
# 317       SS Iyer  Ravi Bishnoi              0  ...         0            0
#
#      noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 110            0             0             0           0           0
# 121            0             0             0           0           0
# 128            0             0             0           0           0
# 221            0             0             0           0           0
# 317            0             0             0           0           0
#
#      player_dismissed dismissal_kind fielder
# 110          TA Boult         bowled     NaN
# 121         SR Watson            lbw     NaN
# 128           M Vijay            lbw     NaN
# 221         RA Jadeja            lbw     NaN
# 317           RR Pant         bowled     NaN
#
# [5 rows x 21 columns]

# %%
hwt['bowler'].value_counts()[:10].plot(kind='bar')
